# %%
import pandas as pd
import numpy as np
import geopandas as gpd
pd.set_option('display.max_columns', None)

# %%
# PENDIENTE

# URL WEB: CAMBIAR ACRÓNIMO POR "NUM_ARTÍCULO"

# %%
df_obras = pd.read_csv('recibido/ivnf4_chronoforms_data_xii-biau-panorama-de-obras-final.csv')
df_obras.head()
# Out:
#    aid  user_id              created             modified  \
# 0   20        0  2022-02-23 12:46:55  2022-02-24 08:38:47
# 1   21        0  2022-02-23 17:02:04  2022-02-24 08:38:47
# 2   22        0  2022-02-23 17:05:26  2022-02-24 08:38:47
# 3   23        0  2022-02-23 23:58:08  2022-02-24 08:38:47
# 4   24        0  2022-02-24 08:38:47  2022-02-24 08:38:47
#
#                                          titulo_Obra  \
# 0                                               VU4B
# 1                      Habitando una galería de arte
# 2                            Seis casas y un jardín
# 3                  Pop Up Pandémica Hotel San Cibrao
# 4  Humanización de depósito de agua y creación de...
#
#                                              autores acronimo   fecha_fin  \
# 0                                               TDA®   TDA454  08-12-2020
# 1  Filipe Magalhães, Ana Luisa Soares, Ahmed Belk...   XYZ097  30-09-2021
# 2  Filipe Magalhães, Ana Luisa Soares, Ahmed Belk...   XYZ075  30-08-2019
# 3  MOL Arquitectura (Muiños Otero López Arquitect...    POP22  No procede
# 4  MOL Arquitectura (Muiños Otero López Arquitect...    XCB00  No procede
#
#   fecha_fin_espana                                            memoria  \
# 0       No procede  Creo que uno no puede conseguir una expresión ...
# 1       No procede  Un bajo comercial de un común y estrecho bloqu...
# 2       No procede  Dos edificios con una apariencia similar, uno ...
# 3       27-03-2021  Antecedentes_\r\nLa irrupción de la Covid-19, ...
# 4       23-03-2021  Antecedentes_\r\nLa actuación planteada preten...
#
#                               Tipo_Obra  \
# 0                            Obra nueva
# 1  Ampliación, reforma o rehabilitación
# 2  Ampliación, reforma o rehabilitación
# 3                      Proyecto efímero
# 4                       Proyecto urbano
#
#                                        colaboradores  \
# 0  Colaboradores: Gustavo Ontaneda, Alberto Martí...
# 1  Francesca Girardi\r\nAna Lima\r\nVirginia Ricc...
# 2                    Rute Peixoto\r\nPaulo Sousa\r\n
# 3  Arquitectos: Cecilia L. Muiños y Juanjo Otero ...
# 4  Arquitectos:Cecilia López Muiños y Juanjo Oter...
#
#                                                 usos  \
# 0                                    ["Residencial"]
# 1                        ["Residencial","Servicios"]
# 2                  ["Residencial","Espacios libres"]
# 3                                      ["Servicios"]
# 4  ["Espacios libres","Transportes e infraestruct...
#
#                                       situacion_obra  \
# 0                 8 DE DICIEMBRE CASI GUILLERMO LEOZ
# 1        Rua Moreira de Assunção 11, 4000-374 Oporto
# 2             Rua de São Dinis 593, 4250-428 Oporto.
# 3  Ricardo Martín Esperanza, 12, 32911 San Cibrao...
# 4               Xacebáns_Quintela de Leirado_Ourense
#
#   pais_de_emplazamiento_de_la_obra                propuesta  \
# 0                         Paraguay  20220224083847_biau.pdf
# 1                         Portugal  20220224083847_biau.pdf
# 2                         Portugal  20220224083847_biau.pdf
# 3                           Espana  20220224083847_biau.pdf
# 4                           Espana  20220224083847_biau.pdf
#
#                                               cesion  \
# 0  20220224083847_autorizaci-n-de-cesi-n-gratuita...
# 1  Francisco Ascenção, Ivo Tavares      Filipe Magalhães  +351 913 134 612
# 2           fala, Ricardo Loureiro      Filipe Magalhães  +351 913 134 612
# 3               Héctor Santos-Díez  Cecilia López Muiños         620555720
# 4               Héctor Santos-Díez  Cecilia López Muiños         620555720
#
#                          email                       email2  proteccion_datos  \
# 0            miguel@tda.com.py            miguel@tda.com.py                 1
# 1       fala.atelier@gmail.com       fala.atelier@gmail.com                 1
# 2       fala.atelier@gmail.com       fala.atelier@gmail.com                 1
# 3  cecilia@molarquitectura.com  cecilia@molarquitectura.com                 1
# 4     info@molarquitectura.com     info@molarquitectura.com                 1
#
#    indicar_otros  indica_otros  otros_uso  otros_tipo  presupuesto dimension  \
# 0            NaN           NaN        NaN         NaN         80.0       220
# 1            NaN           NaN        NaN         NaN     145000.0       200
# 2            NaN           NaN        NaN         NaN        120.0       350
# 3            NaN           NaN        NaN         NaN      33613.0       140
# 4            NaN           NaN        NaN         NaN      16806.0   106.30
#
#     moneda medida                                         para_quien  \
# 0  Dólares     M2                           FAMILIA REINER GROSSLING
# 1     Euro     M2  Gracias a que el promotor en este caso es el m...
# 2     Euro     M2  A partir de la idea de vivir en comunidad, uno...
# 3     Euro     M2  El desarrollo del proyecto busca la recuperaci...
# 4     Euro     M2  La propuesta en cuanto al sistema constructivo...
#
#                                              por_que  radios_group  \
# 0  El encargo se da en un barrio en desarrollo de...           NaN
# 1  El hecho de domesticar un espacio que no se co...           NaN
# 2  Uno de sus elementos característicos es la rei...           NaN
# 3  _ Valores \r\nValores asociados a la  rehabili...           NaN
# 4  En plena Red Natura, un elemento funcional com...           NaN
#
#    checkboxes76  impactos                 sociedad  \
# 0           NaN       NaN     ["Equidad espacial"]
# 1           NaN       NaN          ["Usos mixtos"]
# 2           NaN       NaN     ["Equidad espacial"]
# 3           NaN       NaN  ["Espacios accesibles"]
# 4           NaN       NaN                       ""
#
#                                              economa  \
# 0                    ["Accesibilidad a la vivienda"]
# 1  ["Tenencias alternativas","Accesibilidad a la ...
# 2  ["Accesibilidad a la vivienda","Regeneración u...
# 3                            ["Regeneración urbana"]
# 4                            ["Regeneración urbana"]
#
#                                       medio_ambiente  \
# 0    ["Eficiencia energética","Espacios saludables"]
# 1                                 ["Rehabilitación"]
# 2           ["Rehabilitación","Espacios saludables"]
# 3       ["Espacios saludables","Turismo sostenible"]
# 4  ["Reducción emisiones C02","Rehabilitación","T...
#
#                          transversal                            declaracion  \
# 0             ["Ciencias de ciudad"]  20220224083847_declaraci-n-jurada.pdf
# 1                                 ""  20220224083847_declaraci-n-jurada.pdf
# 2                                 ""  20220224083847_declaraci-n-jurada.pdf
# 3  ["Autosuficiencias comunitarias"]  20220224083847_declaraci-n-jurada.pdf
# 4                                 ""  20220224083847_declaraci-n-jurada.pdf
#
#                            cliente  \
# 0           PERLA Y LUIS GROSSLING
# 1                Braddlee y Prince
# 2            Domingo Discreto, Lda
# 3                 DEBALT UP, S.L.
# 4  Concello de Quintela de Leirado
#
#                                     constructora  \
# 0                                           TDA®
# 1                                 Civiflanco lda
# 2                                 Civiflanco lda
# 3  Construcciones Metalicas Elias J. Iglesias SL
# 4                    Jocsa Investimentos, S.L.
#
#                                      direccion
# 0            MONTE ALTO 4545 CASI RAMOS ALFARO
# 1  Rua do Gerês, 11. 4050-286 Oporto, Portugal
# 2  Rua do Gerês, 11. 4050-286 Oporto, Portugal
# 3                             Rúa Liberdade 31
# 4           Rúa Liberdade 31, Ourense (España)

# %%
df_obras.columns
# Out:
# Index(['aid', 'user_id', 'created', 'modified', 'titulo_Obra', 'autores',
#        'acronimo', 'fecha_fin', 'fecha_fin_espana', 'memoria', 'Tipo_Obra',
#        'colaboradores', 'usos', 'situacion_obra',
#        'pais_de_emplazamiento_de_la_obra', 'propuesta', 'cesion', 'imagen1',
#        'imagen1baja', 'imagen2', 'imagen3', 'imagen4', 'imagen5', 'imagen6',
#        'imagen7', 'imagen8', 'imagen9', 'imagen10', 'imagen11',
#        'credito_fotos', 'persona_contacto', 'telefono', 'email', 'email2',
#        'proteccion_datos', 'indicar_otros', 'indica_otros', 'otros_uso',
#        'otros_tipo', 'presupuesto', 'dimension', 'moneda', 'medida',
#        'para_quien', 'por_que', 'radios_group', 'checkboxes76', 'impactos',
#        'sociedad', 'economa', 'medio_ambiente', 'transversal', 'declaracion',
#        'cliente', 'constructora', 'direccion'],
#       dtype='object')

# %%
# AÑADIR URL IMG
suffix_obras = 'http://www.bienalesdearquitectura.es/images/XII_BIAU/Panorama_obras/'
df_obras['img_url'] = suffix_obras+df_obras['imagen1baja']

# AÑADIR URL WEB
suffix_url_web = 'http://www.bienalesdearquitectura.es/index.php/es/?option=com_content&view=article&id='
df_obras['ficha_url'] = df_obras['acronimo']

# %%
# FECHA FIN: UNIFICAR LAS 2 COLUMNAS

# pendiente de acabar
def func_fecha(row):
    if row['fecha_fin']=='No procede':
        return row['fecha_fin_espana']
    else:
        return row['fecha_fin']

# pendiente de acabar
df_obras['fecha'] = df_obras.apply(lambda row: func_fecha(row), axis=1)

# %%
# SELECCIÓN DE COLUMNAS

# rename
rename_cols = {'Tipo_Obra':'tipo_obra',
               'dimension':'escala',
               'sociedad':'im_sociedad',
               'economa':'im_econom',
               'medio_ambiente':'im_ma',
               'transversal':'im_trans',
               'pais_de_emplazamiento_de_la_obra':'pais',
               'acronimo':'acr',
               'fecha':'año'}

# selección + rename
dff = df[['Tipo_Obra',
          'dimension',
          'usos',
          'sociedad',
          'economa',
          'medio_ambiente',
          'transversal',
          'titulo_Obra', 
          'acronimo',
          'fecha', 
          'pais_de_emplazamiento_de_la_obra', 
          'presupuesto',
          'moneda',
          'autores',
          'img_url',
          'ficha_url']].rename(columns=rename_cols)

# %%
# quedarnos con el último registro (en caso de duplicados)
# diccionario ámbitos
# fecha fin / espana

# %%
# url img

# obras
'http://www.bienalesdearquitectura.es/images/XII_BIAU/Panorama_obras/'+file_name

# publicaciones
'http://www.bienalesdearquitectura.es/images/XII_BIAU/Publicaciones/'+file_name

#Programas académicos
'http://www.bienalesdearquitectura.es/images/XII_BIAU/Programas/'+file_name
 
#Acciones al margen
'http://www.bienalesdearquitectura.es/images/XII_BIAU/Acciones/'+file_name

#Trayectoria
'http://www.bienalesdearquitectura.es/images/XII_BIAU/Trayectoria/'+file_name

# url fichas
